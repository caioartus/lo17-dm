# %% [markdown]
# ### Objectif
# Récupérer ça :
# — le numéro de l’article,
# — le numéro du bulletin,
# — la date,
# — la rubrique,
# — le titre de l’article,
# — l’auteur de l’article,
# — le texte de l’article,
# — la ou les images avec leur(s) URL(s) et leur(s) légende(s) respective(s),
# — les informations de contact

# %%
from bs4 import BeautifulSoup
from pathlib import Path
from lxml import etree

# %%
path = Path("../data/BULLETINS/6739.htm")
with open(path) as f:
    content = f.read()
    soup = BeautifulSoup(content, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[92], line 2
#       1 path = Path("../data/BULLETINS/67399.htm")
# ----> 2 with open(path) as f:
#       3     content = f.read()
#       4     soup = BeautifulSoup(content, 'html.parser')
#
# File ~/Desktop/Uni Stuff/LO17/lo17-dm/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:346, in _modified_open(file, *args, **kwargs)
#     339 if file in {0, 1, 2}:
#     340     raise ValueError(
#     341         f"IPython won't let you open fd={file} by default "
#     342         "as it is likely to crash IPython. If you know what you are doing, "
#     343         "you can use builtins' open."
#     344     )
# --> 346 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/BULLETINS/67399.htm'

# %%
from lxml import html

tree = html.fromstring(content)
title = dom.xpath('//*[@id="LayoutTable"]/table/tr[7]/td/table/tr[3]/td[1]/p[1]/span[2]/text()')

# %%
title
# Out:
# ["Identification de gènes clés qui pourraient doper la production d'huile de palme"]
