# %% [markdown]
# ### Objectif
# Récupérer ça :
# — le numéro de l’article,
# — le numéro du bulletin,
# — la date,
# — la rubrique,
# — le titre de l’article,
# — l’auteur de l’article,
# — le texte de l’article,
# — la ou les images avec leur(s) URL(s) et leur(s) légende(s) respective(s),
# — les informations de contact

# %%
from bs4 import BeautifulSoup
from pathlib import Path

# %%
path = Path("../data/BULLETINS/67068.htm")
with open(path) as f:
    content = f.read()
    soup = BeautifulSoup(content, 'html.parser')

# %%
soup.get
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN">
#
# <html lang="FR">
# <head>
# <link href="http://www.bulletins-electroniques.com/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="http://www.bulletins-electroniques.com/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <title>2011/06/21 &gt; BE France 258 &gt; Physique : Mathias Fink, un bel exemple de chercheur qui innove</title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="Les Bulletins Electroniques des Ambassades de France - un service ADIT" name="description"/>
# <meta content="index,nofollow,noarchive" name="robots"/>
# <meta content="BE, be, veille, technologique, technologie, scientifique, sciences, science, internationale, mondiale, intelligence, économique, Bulletins, bulletins, Bulletin, bulletin, Electroniques, électroniques, Electronique, électronique, ADIT, adit,  MAE, mae, ambassade, France, france, robotix, majordomix, alertix, ministère, affaires, Etrangères, étrangères, rapports, rapport, experts, expert, diffusion, abonnements, abonnement, gratuit" name="keywords"/>
# <meta content="FM Creator for X / Francois MOILLE" name="generator"/>
# <meta content="http://www.bulletins-electroniques.com" name="identifier-url"/>
# <meta content="Francois MOILLE" name="author"/>
# <meta content="7 days" name="revisit-after"/>
# <style type="text/css">
# <!--
# p { margin-top:0px }
# .style98 { text-align: center; }
# .style26 { font-family: Lucida Grande,Geneva,Arial,Helvetica,Verdana,sans-serif; font-size: 11px; }
# .style21 { font-family: Lucida Grande,Geneva,Arial,Helvetica,Verdana,sans-serif; color: #184875; font-size: 11px; }
# .style3 { font-family: Lucida Grande,Geneva,Arial,Helvetica,Verdana,sans-serif; font-weight: bold; color: #184875; font-size: 11px; }
# .style66 { font-family: Lucida Grande,Geneva,Arial,Helvetica,Verdana,sans-serif; font-weight: bold; font-size: 11px; }
# .style32 { font-family: Lucida Grande,Geneva,Arial,Helvetica,Verdana,sans-serif; font-weight: bold; color: #0c3e6e; font-size: 15px; }
# .style55 { font-family: Lucida Grande,Geneva,Arial,Helvetica,Verdana,sans-serif; font-weight: bold; color: #f63; font-size: 12px; }
# .style42 { font-family: Lucida Grande,Geneva,Arial,Helvetica,Verdana,sans-serif; font-weight: bold; color: #3f668c; font-size: 12px; }
# .style96 { margin-top: 7px; margin-bottom: 7px; }
# .style17 { font-family: Lucida Grande,Geneva,Arial,Helvetica,Verdana,sans-serif; font-weight: bold; color: #f63; font-size: 14px; }
# .style93 { margin-top: 1px; margin-bottom: 2px; }
# .style88 { font-family: Lucida Grande,Geneva,Arial,Helvetica,Verdana,sans-serif; color: #a6a6a6; font-size: 11px; }
# .style95 { font-family: Lucida Grande,Geneva,Arial,Helvetica,Verdana,sans-serif; font-size: 11px; }
# .style85 { font-family: Lucida Grande,Geneva,Arial,Helvetica,Verdana,sans-serif; font-weight: bold; font-size: 11px; }
# .style10 { font-family: Lucida Grande,Geneva,Arial,Helvetica,Verdana,sans-serif; font-weight: bold; color: #f63; font-size: 11px; }
# .style9 { font-family: Lucida Grande,Geneva,Arial,Helvetica,Verdana,sans-serif; color: #f63; font-size: 11px; }
# .style43 { text-align: right; margin-top: 0px; margin-bottom: 7px; }
# .style28 { font-family: Lucida Grande,Geneva,Arial,Helvetica,Verdana,sans-serif; font-weight: bold; color: #fff; font-size: 11px; }
# .style44 { margin-top: 0px; margin-bottom: 7px; }
# .style23 { text-align: right; margin-top: 7px; margin-bottom: 7px; }
# .style15 { font-family: Lucida Grande,Geneva,Arial,Helvetica,Verdana,sans-serif; color: #fff; font-size: 11px; }
# .style61 { font-family: Lucida Grande,Geneva,Arial,Helvetica,Verdana,sans-serif; color: #fff; font-size: 10px; }
# .style13 { text-align: right; }
# .style24 { text-align: center; margin-top: 9px; margin-bottom: 9px; }
# .style7 { font-family: Lucida Grande,Geneva,Arial,Helvetica,Verdana,sans-serif; color: #25517d; font-size: 7px; }
# .style86 { font-family: Lucida Grande,Geneva,Arial,Helvetica,Verdana,sans-serif; font-weight: bold; color: #fff; font-size: 12px; }
# .style80 { font-family: Lucida Grande,Geneva,Arial,Helvetica,Verdana,sans-serif; font-weight: bold; font-size: 10px; }
# .style30 { font-family: Lucida Grande,Geneva,Arial,Helvetica,Verdana,sans-serif; font-size: 10px; }
# .FWExtra { }
# .FWExtra a:link { color: #FFFFFF; outline: none; text-decoration: none; }
# .FWExtra a:active { color: #184875; outline: none; text-decoration: none; }
# .FWExtra a:visited { color: #FFFFFF; outline: none; text-decoration: none; }
# .FWExtra a:hover { color: #184875; outline: none; text-decoration: none; }
# .FWExtra1 { }
# .FWExtra1 a:link { color: #FFFFFF; outline: none; text-decoration: none; }
# .FWExtra1 a:active { color: #FF6633; outline: none; text-decoration: none; }
# .FWExtra1 a:visited { color: #FFFFFF; outline: none; text-decoration: none; }
# .FWExtra1 a:hover { color: #FF6633; outline: none; text-decoration: none; }
# .FWExtra2 { }
# .FWExtra2 a:link { color: #184875; outline: none; text-decoration: none; }
# .FWExtra2 a:active { color: #FF6633; outline: none; text-decoration: none; }
# .FWExtra2 a:visited { color: #184875; outline: none; text-decoration: none; }
# .FWExtra2 a:hover { color: #FF6633; outline: none; text-decoration: none; }
# .FWExtra3 { }
# .FWExtra3 a:link { color: #FFFFFF; outline: none; text-decoration: none; }
# .FWExtra3 a:active { color: #FFCC66; outline: none; text-decoration: none; }
# .FWExtra3 a:visited { color: #FFFFFF; outline: none; text-decoration: none; }
# .FWExtra3 a:hover { color: #FFCC66; outline: none; text-decoration: none; }
# -->
# </style>
# <link href="http://www.bulletins-electroniques.com/rss/be_france.xml" rel="alternate" title="BE France RSS" type="application/rss+xml">
# <script src="/analytix/?js" type="text/javascript"></script>
# <script type="text/javascript">
#
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-21112492-1']);
#   _gaq.push(['_setCustomVar', 1, 'Type', 'Actualites', 3]);
#   _gaq.push(['_setCustomVar', 2, 'Pays', 'France', 3]);
#   _gaq.push(['_setCustomVar', 3, 'Bulletin', 'BE_France', 3]);
#   _gaq.push(['_setCustomVar', 4, 'Numero', 'BE_France_258', 3]);
#   _gaq.push(['_setCustomVar', 5, 'Code', 'Actualite_67068', 3]);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#
# </script>
# <meta content="true" name="MSSmartTagsPreventParsing"/>
# <script language="javascript" type="text/javascript"><!--
#
# var fwIsNetscape = navigator.appName == 'Netscape';
#
#
# fwLoad = new Object;
# function FWLoad(image)
# {
# 	if (!document.images)
# 		return null;
# 	if (!fwLoad[image])
# 	{
# 		fwLoad[image]=new Image;
# 		fwLoad[image].src=image;
# 	}
# 	return fwLoad[image].src;
# }
#
#
# fwRestore = new Object;
# function FWRestore(msg,chain)
# {
# 	if (document.images)
# 		for (var i in fwRestore)
# 		{
# 			var r = fwRestore[i];
# 			if (r && (!chain || r.chain==chain) && r.msg==msg)
# 			{
# 				r.src = FWLoad(r.old);
# 				fwRestore[i]=null;
# 			}
# 		}
# }
#
#
# function FWLSwap(name,msg,newImg,layer,chain,trigger)
# {
# 	var r = fwRestore[name];
# 	if (document.images && (!r || r.msg < msg))
# 	{
# 		var uselayers = fwIsNetscape && document.layers && layer != '';
# 		var hld = (uselayers) ? document.layers[layer].document : document;
# 		var im = hld[name];
# 		if (!im.old) im.old = im.src;
# 		im.msg = msg;
# 		im.chain = chain;
# 		im.trigger = trigger;
# 		if (newImg) im.src = FWLoad(newImg);
# 		fwRestore[name] = im;
# 	}
# }
#
#
# function FWCallHit(func,targNum,msg)
# {
# 	if(func)
# 		for (var i in func)
# 			func[i](targNum,msg);
# }
# function FW_Hit(frameset,chain,targNum,msg)
# {
# 	if (frameset && frameset.length)
# 		for (var i=0 ; i <frameset.length ; i++)
# 		{
# 			FW_Hit(frameset[i].frames,chain,targNum,msg);
# 			FWCallHit(top["FT_"+chain],targNum,msg);
# 			FWCallHit(frameset[i].window["FT_"+chain],targNum,msg);
# 		}
# 	else
# 		FWCallHit(window["FT_"+chain],targNum,msg);
# }
#
#
# fwHit = new Object;
# function FWSlave(frameset,chain,targNum,msg)
# {
# 	if (msg==1) fwHit[chain]=targNum;
# 	FW_Hit(frameset,chain,targNum,1);
# }
#
# function FWSRestore(frameset,chain)
# {
# 	var hit=fwHit[chain];
# 	if (hit)
# 		FW_Hit(frameset,chain,hit,0);
# 	fwHit[chain]=null;
# }
#
# function FWPreload()
# {
# 	FWLoad("../../Resources/haut05off.png");
# 	FWLoad("../../Resources/haut05on.png");
# 	FWLoad("../../Resources/haut06off.png");
# 	FWLoad("../../Resources/haut06on.png");
# 	FWLoad("../../Resources/haut07off.png");
# 	FWLoad("../../Resources/haut07on.png");
# 	FWLoad("../../Resources/haut08off.png");
# 	FWLoad("../../Resources/haut08on.png");
# 	FWLoad("../../Resources/haut09off.png");
# 	FWLoad("../../Resources/haut09on.png");
# 	FWLoad("../../Resources/haut10off.png");
# 	FWLoad("../../Resources/haut10on.png");
# 	FWLoad("../../Resources/haut12.png");
# 	FWLoad("../../Resources/haut12slave01.png");
# 	FWLoad("../../Resources/haut12slave02.png");
# 	FWLoad("../../Resources/haut12slave03.png");
# 	FWLoad("../../Resources/haut12slave04.png");
# 	FWLoad("../../Resources/haut12slave05.png");
# 	FWLoad("../../Resources/haut12slave06.png");
# 	FWLoad("../../Resources/haut12slave07.png");
# }
#
# function FWLHitSwap(layer,name,num)
# {
# 	var image = arguments[num+3];
# 	if (document.images && image)
# 	{
# 		var uselayers = fwIsNetscape && document.layers && layer != '';
# 		var hld = (uselayers) ? document.layers[layer].document : document;
# 		hld[name].src = FWLoad(image);
# 	}
# }
#
#
# //-->
# </script></link></head>
# <body bgcolor="#25517d" leftmargin="0" marginheight="0" marginwidth="0" onload="FWPreload()" topmargin="0">
# <div align="center" id="LayoutTable">
# <table border="0" cellpadding="0" cellspacing="0" width="802">
# <tr valign="top">
# <td colspan="3"><a href="http://www.bulletins-electroniques.com" onfocus="this.blur();" onmouseout="FWRestore(1,'Indigo',7);FWSRestore(top.frames,'Indigo')" onmouseover="FWRestore(1,'Indigo');FWSRestore(top.frames,'Indigo');FWSlave(top.frames,'Indigo',7,1)"><img alt="" border="0" height="59" src="../../Resources/haut01.png" width="435"/></a></td>
# <td colspan="6"><a href="http://www.bulletins-electroniques.com/go/01.php" onfocus="this.blur();"><img alt="" border="0" height="59" src="../../Resources/haut02pub01.png" width="365"/></a></td>
# <td height="59"></td>
# </tr>
# <tr valign="top">
# <td colspan="9"><img alt="" border="0" height="6" src="../../Resources/haut03.png" width="800"/></td>
# <td height="6"></td>
# </tr>
# <tr valign="top">
# <td><img alt="" border="0" height="21" src="../../Resources/haut04.png" width="274"/></td>
# <td><a href="http://www.bulletins-electroniques.com/go/menu_01.php" onfocus="this.blur();" onmouseout="FWRestore(1,'Indigo',1);FWSRestore(top.frames,'Indigo')" onmouseover="FWRestore(1,'Indigo');FWSRestore(top.frames,'Indigo');FWSlave(top.frames,'Indigo',1,1);FWLSwap('img2',1,'../../Resources/haut05on.png','','Indigo',1)"><img alt="" border="0" height="21" name="img2" src="../../Resources/haut05off.png" width="87"/></a></td>
# <td colspan="2"><a href="http://www.bulletins-electroniques.com/go/menu_02.php" onfocus="this.blur();" onmouseout="FWRestore(1,'Indigo',2);FWSRestore(top.frames,'Indigo')" onmouseover="FWRestore(1,'Indigo');FWSRestore(top.frames,'Indigo');FWSlave(top.frames,'Indigo',2,1);FWLSwap('img3',1,'../../Resources/haut06on.png','','Indigo',2)"><img alt="" border="0" height="21" name="img3" src="../../Resources/haut06off.png" width="86"/></a></td>
# <td><a href="http://www.bulletins-electroniques.com/go/menu_03.php" onfocus="this.blur();" onmouseout="FWRestore(1,'Indigo',3);FWSRestore(top.frames,'Indigo')" onmouseover="FWRestore(1,'Indigo');FWSRestore(top.frames,'Indigo');FWSlave(top.frames,'Indigo',3,1);FWLSwap('img4',1,'../../Resources/haut07on.png','','Indigo',3)"><img alt="" border="0" height="21" name="img4" src="../../Resources/haut07off.png" width="77"/></a></td>
# <td><a href="http://www.bulletins-electroniques.com/go/menu_04.php" onfocus="this.blur();" onmouseout="FWRestore(1,'Indigo',4);FWSRestore(top.frames,'Indigo')" onmouseover="FWRestore(1,'Indigo');FWSRestore(top.frames,'Indigo');FWSlave(top.frames,'Indigo',4,1);FWLSwap('img5',1,'../../Resources/haut08on.png','','Indigo',4)"><img alt="" border="0" height="21" name="img5" src="../../Resources/haut08off.png" width="95"/></a></td>
# <td><a href="http://www.bulletins-electroniques.com/go/menu_05.php" onfocus="this.blur();" onmouseout="FWRestore(1,'Indigo',5);FWSRestore(top.frames,'Indigo')" onmouseover="FWRestore(1,'Indigo');FWSRestore(top.frames,'Indigo');FWSlave(top.frames,'Indigo',5,1);FWLSwap('img6',1,'../../Resources/haut09on.png','','Indigo',5)"><img alt="" border="0" height="21" name="img6" src="../../Resources/haut09off.png" width="70"/></a></td>
# <td><a href="http://www.bulletins-electroniques.com/go/menu_06.php" onfocus="this.blur();" onmouseout="FWRestore(1,'Indigo',6);FWSRestore(top.frames,'Indigo')" onmouseover="FWRestore(1,'Indigo');FWSRestore(top.frames,'Indigo');FWSlave(top.frames,'Indigo',6,1);FWLSwap('img7',1,'../../Resources/haut10on.png','','Indigo',6)"><img alt="" border="0" height="21" name="img7" src="../../Resources/haut10off.png" width="95"/></a></td>
# <td><img alt="" border="0" height="21" src="../../Resources/haut11.png" width="16"/></td>
# <td height="21"></td>
# </tr>
# <tr valign="top">
# <td colspan="9"><img alt="" border="0" height="19" name="img1" src="../../Resources/haut12.png" width="800"/></td>
# <td height="19"></td>
# </tr>
# <tr valign="top">
# <td colspan="9"><img alt="" border="0" height="26" src="../../Resources/haut13gps34.png" width="800"/></td>
# <td height="26"></td>
# </tr>
# <tr valign="top">
# <td colspan="9"><img alt="" border="0" height="14" src="../../Resources/haut14.png" width="800"/></td>
# <td height="14"></td>
# </tr>
# <tr valign="top">
# <td colspan="9">
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td bgcolor="#99aec2" class="FWExtra" colspan="3" rowspan="3" valign="top" width="160">
# <p class="style98"><img align="middle" alt="" border="0" height="110" hspace="0" src="http://www.bulletins-electroniques.com/Resources_fm/drapeau01/france.jpeg" vspace="0" width="160"/><br/><img alt="spacer" border="0" height="8" src="../../Resources/_clear.gif" width="60"/><br/><img align="absbottom" alt="" border="0" height="27" hspace="0" src="http://www.bulletins-electroniques.com/Resources_fm/ambassade01/france.png" vspace="0" width="160"/><br/><img alt="spacer" border="0" height="4" src="../../Resources/_clear.gif" width="60"/><br/><!--htdig_noindex--><a href="http://www.bulletins-electroniques.com/coordonnees/be_france.htm" onfocus="this.blur();"><span class="style26" style="color:inherit">Coordonnées</span></a><span class="style21"> </span><span class="style3">&gt;&gt;</span><span class="style26"><br/></span><img alt="spacer" border="0" height="10" src="../../Resources/_clear.gif" width="60"/><span class="style26"><br/></span><img align="middle" alt="" border="0" height="2" hspace="0" src="http://www.bulletins-electroniques.com/Resources_fm/makeup/tiret_02.png" vspace="0" width="128"/><span class="style26"><br/></span><img alt="spacer" border="0" height="8" src="../../Resources/_clear.gif" width="60"/><span class="style26"><br/></span><span class="style3">Toute l'actualité :</span><span class="style26"><br/></span><img alt="spacer" border="0" height="3" src="../../Resources/_clear.gif" width="60"/><span class="style26"><br/></span><a href="http://www.bulletins-electroniques.com/actualites/pays/france.php" onfocus="this.blur();"><span class="style66" style="color:inherit">France</span></a><span class="style3"> &gt;&gt;</span><span class="style26"><br/></span><img alt="spacer" border="0" height="3" src="../../Resources/_clear.gif" width="60"/><span class="style26"><br/></span><a href="http://www.bulletins-electroniques.com/actualites/dernieres_parutions.php" onfocus="this.blur();"><span class="style66" style="color:inherit">Monde</span></a><span class="style3"> &gt;&gt;</span><span class="style26"><br/></span><img alt="spacer" border="0" height="6" src="../../Resources/_clear.gif" width="60"/><span class="style26"><br/></span><span class="style3">Tous les rapports :</span><span class="style26"><br/></span><img alt="spacer" border="0" height="3" src="../../Resources/_clear.gif" width="60"/><span class="style26"><br/></span><a href="http://www.bulletins-electroniques.com/rapports/pays/france.php" onfocus="this.blur();"><span class="style66" style="color:inherit">France</span></a><span class="style3"> &gt;&gt;</span><span class="style26"><br/></span><img alt="spacer" border="0" height="3" src="../../Resources/_clear.gif" width="60"/><a href="http://www.bulletins-electroniques.com/cgi/htsearch?config=bulletins_electroniques_51_slave&amp;restrict=&amp;exclude=&amp;keywords=4444444001&amp;Envoi=rechercher&amp;method=and&amp;format=long&amp;sort=revtitle" onfocus="this.blur();"><span class="style26" style="color:inherit"><br/></span></a><a href="http://www.bulletins-electroniques.com/rapports.php" onfocus="this.blur();"><span class="style66" style="color:inherit">Monde</span></a><span class="style3"> &gt;&gt;</span><span class="style26"><br/></span><img alt="spacer" border="0" height="8" src="../../Resources/_clear.gif" width="60"/><span class="style26"><br/></span><img align="middle" alt="" border="0" height="2" hspace="0" src="http://www.bulletins-electroniques.com/Resources_fm/makeup/tiret_02.png" vspace="0" width="128"/><span class="style26"><br/></span><img alt="spacer" border="0" height="10" src="../../Resources/_clear.gif" width="60"/><span class="style26"><br/></span><a href="http://www.bulletins-electroniques.com/rss/be_france.xml" onfocus="this.blur();"><img align="absbottom" alt="" border="0" height="14" hspace="0" src="http://www.bulletins-electroniques.com/Resources_fm/rssimage02/rssbefrance.png" vspace="0" width="118"/></a><span class="style66"><br/></span><img alt="spacer" border="0" height="5" src="../../Resourc ...
# <td bgcolor="#bfccd9" valign="top" width="16">
# <p><img alt="spacer" border="0" height="32" src="../../Resources/_clear.gif" width="16"/></p></td>
# <td bgcolor="#bfccd9" colspan="2" valign="middle" width="464">
# <p><span class="style32">BE France 258  </span><span class="style55">&gt;&gt;</span><span class="style42">  21/06/2011</span></p></td>
# <td bgcolor="#99aec2" valign="middle" width="16"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="1"/></td>
# <td bgcolor="#99aec2" class="FWExtra1" valign="middle" width="133">
# <p class="style96"><!--htdig_noindex--><a href="http://www.bulletins-electroniques.com/be_france_258.htm" onfocus="this.blur();"><span class="style66" style="color:inherit">&gt;&gt; Sommaire</span></a><!--/htdig_noindex--><span class="style3"></span></p></td>
# <td bgcolor="#99aec2" valign="top" width="11"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="1"/></td>
# </tr>
# <tr>
# <td bgcolor="#f3f5f8" rowspan="3" valign="top" width="16"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="1"/></td>
# <td bgcolor="#f3f5f8" valign="top" width="452">
# <p><img alt="spacer" border="0" height="3" src="../../Resources/_clear.gif" width="54"/></p></td>
# <td bgcolor="#f3f5f8" rowspan="3" valign="top" width="12"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="1"/></td>
# <td bgcolor="#dae1e8" rowspan="2" valign="top" width="16"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="1"/></td>
# <td bgcolor="#dae1e8" valign="top" width="133"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="1"/></td>
# <td bgcolor="#dae1e8" rowspan="2" valign="top" width="11"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="1"/></td>
# </tr>
# <tr>
# <td bgcolor="#f3f5f8" class="FWExtra2" valign="top" width="452">
# <p class="style96"><span class="style42">Focus<br/></span><span class="style17">Physique : Mathias Fink, un bel exemple de chercheur qui innove</span></p>
# <p class="style93"><!--htdig_noindex--><span class="style88">http://www.bulletins-electroniques.com/actualites/67068.htm<!--/htdig_noindex--></span><span class="style88"></span></p>
# <p class="style96"><span class="style95">Le 27 avril dernier, le CNRS décernait pour la première fois la Médaille de l'Innovation, dont Valérie Pécresse, ministre de l'Enseignement Supérieur et de la Recherche est à l'origine de la création. Le CNRS souhaite ainsi honorer des chercheurs et ingénieurs travaillant dans des établissements publics de recherche, des universités, des grandes écoles mais aussi des industriels qui développent des innovations marquantes. Pour cette première édition, cette nouvelle distinction a été attribuée à trois chercheurs réputés : l'économiste Esther Duflo, le roboticien François Pierrot et le physicien Mathias Fink. Directeur de l'Institut Langevin "Ondes et Images", créé en janvier 2009 au sein de l'Ecole de Physique et de Chimie Industrielles de la Ville de Paris (ESPCI), Mathias Fink est un remarquable exemple de ces chercheurs qui innovent. Les travaux de son équipe ont en effet abouti à la création de quatre start-ups, qui totalisent 230 personnes, dans des domaines aussi variés que la médecine, les télécommunications, le multimédia ou encore les objets tactiles.<br><br>"J'aime transformer des idées de physique très fondamentale en produits innovants", précise d'emblée Mathias Fink. Mais pour y parvenir, il fallait trouver le "terrain" propice. Et c'est à la fin des années 1980, à l'occasion d'une rencontre avec Georges Charpak, le prix Nobel de Physique 1992, qu'il va le découvrir, au coeur de la Montagne Sainte Geneviève, en plein Paris. Alors physicien au sein d'un des plus grands laboratoires français de physique du solide, Mathias Fink souhaite faire de l'innovation autour du concept de renversement du temps. De la "belle physique" comme la qualifient les connaisseurs, qui plus est qui intéresse quatre grands industriels du secteur aéronautique (Dassault, Aerospatial, Snecma, Turboméca), prêts à financer des travaux. Mais à cette époque, le milieu de la recherche est encore peu enclin à travailler avec l'industrie, d'autant plus si celle-ci est "militaro-industrielle". Aussi Mathias Fink se retrouve isolé. Georges Charpak lui propose alors de rencontrer Pierre-Gilles de Gennes, alors directeur de l'ESPCI, et Jacques Lewiner, le directeur scientifique. "C'est un endroit sympathique", lui précise Georges Charpak. "Je les ai rencontré. L'endroit était en effet très sympathique. Ils m'ont alors dit : vous voulez Innovez ? Alors venez", résume Mathias Fink qui ajoute : "cela a été la chance de ma carrière".<br><br><b>Vous êtes chercheur : amusez-vous</b><br><br>C'est ainsi que dès 1990, ce physicien crée le Laboratoire Ondes et Acoustique, dans une école qu'il qualifie d'"unique". "Innover est particulièrement bien vu à l'ESPCI, et l'on vous donne le feu vert du moment que l'idée proposée est très originale", précise-t-il. Autre particularité de cette école vraiment pas comme les autres Grandes Ecoles, la pluridisciplinarité qui y règne. Ne cherchez pas, vous n'y trouverez pas comme ailleurs un département de physique, un département de chimie et un département de biologie. "Ici, on vous dit dès le départ : vous êtes chercheur, amusez-vous", souligne-t-il avec une pointe d'humour. Et c'est en s'amusant que lui et son équipe ont développé les fameux miroirs à retournement temporel qui permettent d'échantillonner et d'enregistrer un champ acoustique incident puis de le réémettre dans une chronologie inversée. Mathias Fink et ses collaborateurs se sont rendus compte en effet que faire revivre à une onde sa vie passée permettait de focaliser cette onde à sa source d'une façon très efficace. Ils commencèrent alors à travailler d'abord sur les ultrasons, puis sur les ondes sismiques et les micro-ondes.<br><br>Cette équipe aurait pu se limiter à publier d'excellents papiers dans des publications réputées comme Physical Review. Mais ces chercheurs ont compris très vite qu'au-delà de cette "belle physique", il y avait des applications potentielles. Ainsi le renversement du temps permettait de brûler ...
# <td bgcolor="#dae1e8" class="FWExtra2" valign="top" width="133">
# <p><!--htdig_noindex--><img alt="spacer" border="0" height="5" src="../../Resources/_clear.gif" width="60"/><span class="style85"><br/><a href="67069.htm"> &gt;&gt; Suivant </a><br/></span><img alt="spacer" border="0" height="6" src="../../Resources/_clear.gif" width="60"/><span class="style85"><br/></span><span class="style85"></span><span class="style95"><br/></span><img alt="spacer" border="0" height="8" src="../../Resources/_clear.gif" width="60"/><span class="style95"><br/></span><img align="middle" alt="" border="0" height="2" hspace="0" src="http://www.bulletins-electroniques.com/Resources_fm/makeup/tiret_01.png" vspace="0" width="128"/><span class="style95"><br/></span><img alt="spacer" border="0" height="8" src="../../Resources/_clear.gif" width="60"/><span class="style95"><br/>Partager cette page :<br/></span><table>
# <tr>
# <td>
# <div class="style95" style="float: left; padding: 2px 0px 0px 0px;">
# <a class="twitter-share-button" data-count="none" data-lang="fr" data-text="Physique : Mathias Fink, un bel exemple de chercheur qui innove (Focus)..." data-url="http://www.bulletins-electroniques.com/actualites/67068.htm" data-via="Les_BE" href="http://twitter.com/share">Tweet</a>
# <script src="http://platform.twitter.com/widgets.js" type="text/javascript"></script>
# </div>
# </td>
# </tr>
# <tr>
# <td>
# <div class="style95" style="float: left; padding: 2px 0px 6px 0px;">
# <a class="fb_share" name="fb_share" share_url="http://www.bulletins-electroniques.com/actualites/67068.htm" type="button">Partager</a>
# <script src="http://static.ak.fbcdn.net/connect.php/js/FB.Share" type="text/javascript"></script>
# </div>
# </td>
# </tr>
# </table>
# <img align="middle" alt="" border="0" height="2" hspace="0" src="http://www.bulletins-electroniques.com/Resources_fm/makeup/tiret_01.png" vspace="0" width="128"/><span class="style95"><br/></span><img alt="spacer" border="0" height="8" src="../../Resources/_clear.gif" width="60"/><span class="style95"><br/></span><a href="http://www.bulletins-electroniques.com/actualites/067/67068_vi.htm" onfocus="this.blur();" target="_blank"><span class="style95" style="color:inherit">Version imprimable</span></a><span class="style95"> </span><span class="style10">&gt;&gt;</span><span class="style95"><br/></span><img alt="spacer" border="0" height="6" src="../../Resources/_clear.gif" width="60"/><span class="style95"><br/></span><a href="mailto:?subject=[BE France 258] Physique : Mathias Fink, un bel exemple de chercheur qui innove&amp;body=Bonjour - Une information parue dans le BE France 258 du 21/06/2011 pourrait vous interesser : 'Physique : Mathias Fink, un bel exemple de chercheur qui innove' - Pour en prendre connaissance connectez-vous sur http://www.bulletins-electroniques.com/actualites/67068.htm - Ce bulletin est redige par l'ADIT et est diffuse gratuitement par l'ADIT - Bonne lecture ! Cordialement" onfocus="this.blur();"><span class="style95" style="color:inherit">Transmettre cette info par email</span></a><span class="style95"> </span><span class="style10">&gt;&gt;</span><span class="style95"><br/></span><img alt="spacer" border="0" height="6" src="../../Resources/_clear.gif" width="60"/><span class="style95"><br/></span><a href="mailto:?subject=bulletins-electroniques.com : toute la veille technologique internationale&amp;body=Bonjour - Je vous recommande ce site utile et gratuit sur la veille technologique internationale : http://www.bulletins-electroniques.com - Bonne lecture ! Cordialement" onfocus="this.blur();"><span class="style95" style="color:inherit">Recommander ce site à un collègue / ami</span></a><span class="style95"> </span><span class="style10">&gt;&gt;</span><span class="style95"><br/></span><img alt="spacer" border="0" height="8" src="../../Resources/_clear.gif" width="60"/><span class="style95"><br/></span><img align="middle" alt="" border="0" height="2" hspace="0" src="http://www.bulletins-electroniques.com/Resources_fm/makeup/tiret_01.png" vspace="0" width="128"/><span class="style95"><br/></span><img alt="spacer" border="0" height="8" src="../../Resources/_clear.gif" width="60"/><span class="style95"><br/></span><a href="http://www.bulletins-electroniques.com/emailix/abonnements.htm" onfocus="this.blur();"><span class="style95" style="color:inherit">S'abonner au<br/>BE France</span></a><span class="style95"> </span><span class="style10">&gt;&gt;</span><span class="style95"><br/></span><img alt="spacer" border="0" height="8" src="../../Resources/_clear.gif" width="60"/><span class="style95"><br/></span><img align="middle" alt="" border="0" height="2" hspace="0" src="http://www.bulletins-electroniques.com/Resources_fm/makeup/tiret_01.png" vspace="0" width="128"/><span class="style95"><br/></span><img alt="spacer" border="0" height="8" src="../../Resources/_clear.gif" width="60"/><span class="style95"><br/></span><a href="../../faq.htm" onfocus="this.blur();"><span class="style95" style="color:inherit">FAQ / foire aux questions</span></a><span class="style95"> </span><span class="style10">&gt;&gt;</span><span class="style95"><br/></span><img alt="spacer" border="0" height="6" src="../../Resources/_clear.gif" width="60"/><span class="style95"><br/></span><a href="../../conditions_utilisation.htm" onfocus="this.blur();"><span class="style95" style="color:inherit">Conditions d'utilisation</span></a><span class="style95"> </span><span class="style10">&gt;&gt;</span><!--/htdig_noindex--><span class="style9"></span></p></td>
# </tr>
# <tr>
# <td bgcolor="#99aec2" colspan="3" valign="top" width="160">
# <p><img alt="spacer" border="0" height="10" src="../../Resources/_clear.gif" width="60"/></p></td>
# <td bgcolor="#f3f5f8" valign="top" width="452"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="1"/></td>
# <td bgcolor="#dae1e8" colspan="3" valign="top" width="160"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="1"/></td>
# </tr>
# <tr>
# <td bgcolor="#6584a3" rowspan="5" valign="top" width="6"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="1"/></td>
# <td bgcolor="#6584a3" valign="top" width="148">
# <p><img alt="spacer" border="0" height="8" src="../../Resources/_clear.gif" width="60"/></p></td>
# <td bgcolor="#6584a3" rowspan="5" valign="top" width="6"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="1"/></td>
# <td bgcolor="#dae1e8" rowspan="5" valign="top" width="16"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="1"/></td>
# <td bgcolor="#dae1e8" valign="top" width="452"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="1"/></td>
# <td bgcolor="#dae1e8" rowspan="5" valign="top" width="12"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="1"/></td>
# <td bgcolor="#b4c3d1" rowspan="5" valign="top" width="16"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="1"/></td>
# <td bgcolor="#b4c3d1" valign="bottom" width="133"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="1"/></td>
# <td bgcolor="#b4c3d1" rowspan="5" valign="top" width="11"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="1"/></td>
# </tr>
# <tr>
# <td bgcolor="#6584a3" valign="top" width="148">
# <p class="style43"><!--htdig_noindex--><span class="style28">Pour en savoir plus, contacts :</span><!--/htdig_noindex--></p></td>
# <td bgcolor="#dae1e8" class="FWExtra2" valign="top" width="452">
# <p class="style44"><span class="style85">Institut Langevin "Ondes et Images" - Mathias Fink - email : <a href="mailto:mathias.fink@espci.fr">mathias.fink@espci.fr</a> - <a href="http://www.institut-langevin.espci.fr">http://www.institut-langevin.espci.fr</a></span></p></td>
# <td bgcolor="#b4c3d1" class="FWExtra1" rowspan="3" valign="bottom" width="133">
# <p class="style23"><!--htdig_noindex--><span class="style15">Code brève<br/>ADIT : </span><a href="http://www.bulletins-electroniques.com/actualites/67068.htm" onfocus="this.blur();"><span class="style95" style="color:inherit">67068</span></a><!--/htdig_noindex--></p></td>
# </tr>
# <tr>
# <td bgcolor="#6584a3" valign="top" width="148">
# <p class="style43"><!--htdig_noindex--><span class="style28"></span><!--/htdig_noindex--></p></td>
# <td bgcolor="#dae1e8" class="FWExtra2" valign="top" width="452">
# <p class="style44"><span class="style95"></span></p></td>
# </tr>
# <tr>
# <td bgcolor="#6584a3" valign="top" width="148">
# <p class="style43"><!--htdig_noindex--><span class="style28">Rédacteur :</span><!--/htdig_noindex--></p></td>
# <td bgcolor="#dae1e8" class="FWExtra2" valign="top" width="452">
# <p class="style44"><span class="style95">ADIT - Jean-François Desessard - email : <a href="mailto:jfd@adit.fr">jfd@adit.fr</a></span></p></td>
# </tr>
# <tr>
# <td bgcolor="#6584a3" valign="top" width="148">
# <p><img alt="spacer" border="0" height="2" src="../../Resources/_clear.gif" width="60"/></p></td>
# <td bgcolor="#dae1e8" valign="top" width="452"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="1"/></td>
# <td bgcolor="#b4c3d1" valign="bottom" width="133"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="1"/></td>
# </tr>
# <tr>
# <td bgcolor="#4b7194" rowspan="2" valign="top" width="6"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="1"/></td>
# <td bgcolor="#4b7194" valign="top" width="148">
# <p><img alt="spacer" border="0" height="5" src="../../Resources/_clear.gif" width="60"/></p></td>
# <td bgcolor="#4b7194" rowspan="2" valign="top" width="6"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="1"/></td>
# <td bgcolor="#7290ab" rowspan="2" valign="top" width="16"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="1"/></td>
# <td bgcolor="#7290ab" colspan="4" valign="top" width="613"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="1"/></td>
# <td bgcolor="#7290ab" rowspan="2" valign="top" width="11"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="1"/></td>
# </tr>
# <tr>
# <td bgcolor="#4b7194" valign="top" width="148">
# <p class="style13"><!--htdig_noindex--><span class="style15">Origine :</span><!--/htdig_noindex--></p></td>
# <td bgcolor="#7290ab" class="FWExtra3" colspan="4" valign="top" width="613">
# <p><!--htdig_noindex--><span class="style15">BE France numéro 258 (21/06/2011) - ADIT / ADIT - http://www.bulletins-electroniques.com/actualites/67068.htm<!--/htdig_noindex--></span><a href="http://www.bulletins-electroniques.com" onfocus="this.blur();"><span class="style15" style="color:inherit"><br/></span></a><img alt="spacer" border="0" height="4" src="../../Resources/_clear.gif" width="60"/><span class="style61" style="color:inherit"></span></p></td>
# </tr>
# <tr>
# <td bgcolor="#4b7194" valign="top" width="6"><img alt="" height="1" src="../../Resources/_clear.gif" width="6"/></td>
# <td bgcolor="#4b7194" valign="top" width="148"><img alt="" height="1" src="../../Resources/_clear.gif" width="148"/></td>
# <td bgcolor="#4b7194" valign="top" width="6"><img alt="" height="1" src="../../Resources/_clear.gif" width="6"/></td>
# <td bgcolor="#7290ab" valign="top" width="16"><img alt="" height="1" src="../../Resources/_clear.gif" width="16"/></td>
# <td bgcolor="#7290ab" valign="top" width="452"><img alt="" height="1" src="../../Resources/_clear.gif" width="452"/></td>
# <td bgcolor="#7290ab" valign="top" width="12"><img alt="" height="1" src="../../Resources/_clear.gif" width="12"/></td>
# <td bgcolor="#7290ab" valign="top" width="16"><img alt="" height="1" src="../../Resources/_clear.gif" width="16"/></td>
# <td bgcolor="#7290ab" valign="top" width="133"><img alt="" height="1" src="../../Resources/_clear.gif" width="133"/></td>
# <td bgcolor="#7290ab" valign="top" width="11"><img alt="" height="1" src="../../Resources/_clear.gif" width="11"/></td>
# </tr>
# </table>
# </td>
# </tr>
# <tr valign="top">
# <td colspan="9"></td>
# </tr>
# <tr valign="top">
# <td colspan="9"><img alt="" border="0" height="66" src="../../Resources/bas01.png" usemap="#map1" width="800"/></td>
# <td height="66"></td>
# </tr>
# <tr valign="top">
# <td class="FWExtra3" colspan="9" rowspan="2">
# <p class="style98"><br/><!--htdig_noindex--><span class="style86">[</span><span class="style80">  </span><a href="../../plan_du_site.htm" onfocus="this.blur();"><span class="style80" style="color:inherit">Plan du site</span></a><span class="style80">  </span><span class="style86">|</span><span class="style80">  </span><a href="../../donnees_personnelles.htm" onfocus="this.blur();"><span class="style80" style="color:inherit">Données personnelles &amp; politique de confidentialité</span></a><span class="style80">  </span><span class="style86">|</span><span class="style80">  </span><a href="../../limites_responsabilite.htm" onfocus="this.blur();"><span class="style80" style="color:inherit">Limites de responsabilité</span></a><span class="style80">  </span><span class="style86">|</span><span class="style80">  </span><a href="../../faq.htm" onfocus="this.blur();"><span class="style80" style="color:inherit">FAQ</span></a><span class="style80">  </span><span class="style86">|</span><span class="style80">  </span><a href="../../contacts.htm" onfocus="this.blur();"><span class="style80" style="color:inherit">Contacts</span></a><span class="style80">  </span><span class="style86">]<!--/htdig_noindex--></span><span class="style86"></span></p>
# <p class="style98"><!--htdig_noindex--><span class="style86">[</span><span class="style80">  </span><a href="http://www.bulletins-electroniques.com" onfocus="this.blur();"><span class="style80" style="color:inherit">Page d'accueil</span></a><span class="style80">  </span><span class="style86">|</span><span class="style80">  </span><a href="http://www.bulletins-electroniques.com/go/menu_01.php" onfocus="this.blur();"><span class="style80" style="color:inherit">Découvrir</span></a><span class="style80">  </span><span class="style86">|</span><span class="style80">  </span><a href="http://www.bulletins-electroniques.com/go/menu_02.php" onfocus="this.blur();"><span class="style80" style="color:inherit">Consulter</span></a><span class="style80">  </span><span class="style86">|</span><span class="style80">  </span><a href="http://www.bulletins-electroniques.com/go/menu_03.php" onfocus="this.blur();"><span class="style80" style="color:inherit">Recevoir</span></a><span class="style80">  </span><span class="style86">|</span><span class="style80">  </span><a href="http://www.bulletins-electroniques.com/go/menu_04.php" onfocus="this.blur();"><span class="style80" style="color:inherit">Rechercher</span></a><span class="style80">  </span><span class="style86">|</span><span class="style80">  </span><a href="http://www.bulletins-electroniques.com/go/menu_05.php" onfocus="this.blur();"><span class="style80" style="color:inherit">Utiliser</span></a><span class="style80">  </span><span class="style86">|</span><span class="style80">  </span><a href="http://www.bulletins-electroniques.com/go/menu_06.php" onfocus="this.blur();"><span class="style80" style="color:inherit">S'exprimer</span></a><span class="style80">  </span><span class="style86">]<!--/htdig_noindex--></span><span class="style86"></span></p>
# <p class="style98"><!--htdig_noindex--><span class="style61">bulletins-electroniques.com tous droits réservés   -   votre contact : </span><a href="../../contacts.htm" onfocus="this.blur();"><span class="style30" style="color:inherit">François Moille<!--/htdig_noindex--></span></a><span class="style30" style="color:inherit"></span></p>
# <p class="style98"><span class="style30" style="color:inherit"> </span></p></td>
# </tr>
# <tr valign="top">
# </tr>
# <tr valign="top">
# <td colspan="9">
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td valign="bottom" width="800">
# <p class="style24"><span class="style7">4444444001 999920110622 3333333061 1010101017 1010101015  1111111048 55555550062011 6666666059 7777777001</span></p></td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td width="274"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="274"/></td>
# <td width="87"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="87"/></td>
# <td width="74"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="74"/></td>
# <td width="12"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="12"/></td>
# <td width="77"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="77"/></td>
# <td width="95"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="95"/></td>
# <td width="70"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="70"/></td>
# <td width="95"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="95"/></td>
# <td width="16"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="16"/></td>
# <td height="1" width="2"><img alt="" border="0" height="1" src="../../Resources/_clear.gif" width="2"/></td>
# </tr>
# </table>
# <map name="map1">
# <area alt="" coords="564,10,611,58" href="http://www.adit.fr" onfocus="this.blur();" target="_blank"/>
# <area alt="" coords="622,12,772,56" href="http://www.diplomatie.gouv.fr" onfocus="this.blur();" target="_blank"/>
# </map>
# </div>
# <script language="javascript" type="text/javascript"><!--
# function FWImage_Indigo(chain,msg)
# {
# 	if (chain==1)
# 		FWLHitSwap('','img1',msg,'../../Resources/haut12.png','../../Resources/haut12slave01.png');
# 	if (chain==2)
# 		FWLHitSwap('','img1',msg,'../../Resources/haut12.png','../../Resources/haut12slave02.png');
# 	if (chain==3)
# 		FWLHitSwap('','img1',msg,'../../Resources/haut12.png','../../Resources/haut12slave03.png');
# 	if (chain==4)
# 		FWLHitSwap('','img1',msg,'../../Resources/haut12.png','../../Resources/haut12slave04.png');
# 	if (chain==5)
# 		FWLHitSwap('','img1',msg,'../../Resources/haut12.png','../../Resources/haut12slave05.png');
# 	if (chain==6)
# 		FWLHitSwap('','img1',msg,'../../Resources/haut12.png','../../Resources/haut12slave06.png');
# 	if (chain==7)
# 		FWLHitSwap('','img1',msg,'../../Resources/haut12.png','../../Resources/haut12slave07.png');
# }
# window.FT_Indigo=new Object;
# window.FT_Indigo['0']=FWImage_Indigo;
#
# //-->
# </script></body>
# </html>
